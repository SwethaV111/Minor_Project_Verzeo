# %% [markdown]
# The mobile games industry is worth billions of dollars, with companies spending vast amounts of money on the development and marketing of these games to an equally large market. Using this data set, insights can be gained into a sub-market of this market, strategy games. This sub-market includes titles such as Clash of Clans, Plants vs Zombies and Pokemon GO.
#
# Objective: To expose the best combination for strategy games available in the appstore in order to get a good user rating (4.0/5.0 and above)
# •	Perform Data Preparation by cleaning the data and removing null values.
# •	Identify the genres which are more significant and do simple analysis for the distribution according to genres.
# •	Identify Which genres have higher user ratings.
# •	Identify trend of user rating based on pricing.
# •	State your inferences.

# %% [markdown]
# 1.)Perform Data Preparation by cleaning the data and removing null values.

# %%
#importing data frame
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette('husl')

# %%
pwd
# Out:
# 'C:\\Users\\SWETHA\\Downloads'

# %%
app=pd.read_csv('appstore_games .csv')#name of dataframe is app
app
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# ...

# %%
#removing null values
app.dropna()
# Out:
#                                                      URL          ID  \
# 5      https://apps.apple.com/us/app/sudoku-classic-n...   286210009
# 19     https://apps.apple.com/us/app/cool-sudoku-jigs...   290614255
# 75     https://apps.apple.com/us/app/gun-runner/id306...   306165224
# 90     https://apps.apple.com/us/app/uniwar-multiplay...   311456818
# 106    https://apps.apple.com/us/app/towermadness/id3...   316491616
# ...                                                  ...         ...
# 16828  https://apps.apple.com/us/app/zipline-valley/i...  1470146913
# 16842  https://apps.apple.com/us/app/lordz2-io-conque...  1470369387
# 16856  https://apps.apple.com/us/app/smartphone-tycoo...  1470806544
# 16863  https://apps.apple.com/us/app/hero-chess-teamf...  1471007235
# 16932  https://apps.apple.com/us/app/spatula-tft-chea...  1472818549
#
#                                  Name                        Subtitle  \
# ...

# %%
#average user rating
sns.set()
sns.countplot(x="Average User Rating", data=app);

# %% [markdown]
# 2.)Identify the genres which are more significant and do simple analysis for the distribution according to genres.

# %%
genre = app['Primary Genre'].value_counts()
p = figure(x_range=list(map(str, genre.index.values)), 
           plot_height=250, plot_width=1500, title="Primary Genre", 
           toolbar_location=None, 
           tools="")

p.vbar(x=list(map(str, genre.index.values)), 
       top=genre.values, 
       width=0.9, 
       color=Spectral9)

p.xgrid.grid_line_color = None
p.y_range.start = 0
show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-126f56fba313> in <module>
# ----> 1 genre = app['Primary Genre'].value_counts()
#       2 p = figure(x_range=list(map(str, genre.index.values)),
#       3            plot_height=250, plot_width=1500, title="Primary Genre",
#       4            toolbar_location=None,
#       5            tools="")
#
# NameError: name 'app' is not defined

# %% [markdown]
# inference:games are majority followed by education and entertainment

# %% [markdown]
# 3.)Identify trend of user rating based on pricing.

# %%
paid = app[app['Price']>0]
free = app[app['Price']==0]
fig, ax = plt.subplots(1, 2, figsize=(15,8))
sns.countplot(data=paid, y='Average User Rating', ax=ax[0], palette='plasma')
ax[0].set_title('Paid Games')
ax[0].set_xlim([0, 1000])

sns.countplot(data=free, y='Average User Rating', ax=ax[1], palette='viridis')
ax[1].set_title('Free Games')
ax[1].set_xlim([0,1000])
plt.tight_layout();
plt.show()

# %% [markdown]
# Inferences:
# 1. As expected there are less number of paid games than free games
# 2. But Still we cannot see any difference in user ratings of both the categories
# 3. Most of the Games are rated quite good around 4.0-5.0
# 4. It doesn't seem like price has an impact on the ratings as both free and paid games have almost same ratings

# %% [markdown]
# 4.)Inferences

# %%
#1.)Most Expensive game
price = app.sort_values(by='Price', ascending=False)[['Name', 'Price', 'Size', 'Icon URL']]

price.iloc[:, 0:-1]
# Out:
#                                                     Name   Price         Size
# 8807   Cat Simulator: Cute Pet 3D Full - Be a kitten,...  179.99   99716096.0
# 8600              Wild Falcon Survival Simulator 3D Full  179.99  109358080.0
# 9219            Lion Simulator: Wild African Animal Full  179.99   98597888.0
# 8281      Sea Turtle Simulator 3D Full - Ocean Adventure  179.99  111177728.0
# 8177                        Wild Horse 3D Simulator Full  179.99  126033920.0
# ...                                                  ...     ...          ...
# 16951                       War Shooting Battle Survival     NaN  261016576.0
# 16978                           Magic Puzzle Box: 3 in 1     NaN  114580480.0
# 16980                               Block Soldier Sniper     NaN  170358784.0
# 17000                                          Super kid     NaN   11404288.0
# 17001                              Lava Island Adventure     NaN   21191680.0
#
# [17007 rows x 3 columns]

# %% [markdown]
# The first five games are the most expensive games.

# %%
#Most popular game
review = app.sort_values(by='User Rating Count', ascending=False)[['Name', 'Average User Rating', 'Size', 'User Rating Count', 'Icon URL']].head(10)

review.iloc[:, 0:-1]
# Out:
#                                  Name  Average User Rating          Size  \
# 1378                   Clash of Clans                  4.5  1.612196e+08
# 7187                     Clash Royale                  4.5  1.451080e+08
# 13414                     PUBG MOBILE                  4.5  2.384082e+09
# 1921       Plants vs. Zombies\u2122 2                  4.5  1.207634e+08
# 8139                    Pok\xe9mon GO                  3.5  2.815212e+08
# 2410                       Boom Beach                  4.5  2.027858e+08
# 12473  Cash, Inc. Fame & Fortune Game                  5.0  2.459576e+08
# 8632   Idle Miner Tycoon: Cash Empire                  4.5  4.439747e+08
# 38                         TapDefense                  3.5  7.774384e+06
# 3550       Star Wars\u2122: Commander                  4.5  1.230838e+08
#
#        User Rating Count
# 1378           3032734.0
# 7187           1277095.0
# 13414           711409.0
# 1921            469562.0
# 8139            439776.0
# ...

# %% [markdown]
# Clash of clans,Clash Royale and Pubg Mobile are more liked games by user.

# %%
#Best overall game 
best = app.sort_values(by=['Average User Rating', 'User Rating Count'], ascending=False)[['Name', 'Average User Rating', 'User Rating Count', 'Size', 
                                                                                         'Icon URL']].head(10)
best.iloc[:, 0:-1]
# Out:
#                                     Name  Average User Rating  \
# 12473     Cash, Inc. Fame & Fortune Game                  5.0
# 6089                           Egg, Inc.                  5.0
# 14155                          AFK Arena                  5.0
# 8388   South Park: Phone Destroyer\u2122                  5.0
# 13261         From Zero to Hero: Cityman                  5.0
# 15266                     Sushi Bar Idle                  5.0
# 10418                 Fire Emblem Heroes                  5.0
# 1649                         Bloons TD 5                  5.0
# 872                        Naval Warfare                  5.0
# 16434                Idle Roller Coaster                  5.0
#
#        User Rating Count         Size
# 12473           374772.0  245957632.0
# 6089            174591.0   74891264.0
# 14155           156766.0  225711104.0
# 8388            156044.0  130186240.0
# 13261           146729.0  296638464.0
# 15266           123606.0  257325056.0
# ...

# %% [markdown]
# Cash,Inc.Fame&Fortune game is the best overall game with higest average user rating and user rating count.
# There are many other games with 5.0 avg user rating count.
